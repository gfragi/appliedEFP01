# %% [markdown]
# # Variable Assignment

# %% [markdown]
# ## Dynamic Typing
#
# Python uses *dynamic typing*, meaning you can reassign variables to different data types. This makes Python very flexible in assigning data types; it differs from other languages that are *statically typed*.

# %%
my_dogs = 2

# %%
my_dogs
# Out:
# 2

# %%
my_dogs = ['Sammy', 'Frankie']

# %%
my_dogs
# Out:
# ['Sammy', 'Frankie']

# %% [markdown]
# ## Assigning Variables
# Variable assignment follows `name = object`, where a single equals sign `=` is an *assignment operator*

# %%
a = 5

# %%
a
# Out:
# 5

# %% [markdown]
# Here we assigned the integer object `5` to the variable name `a`.<br>Let's assign `a` to something else:

# %%
a = 10

# %%
a
# Out:
# 10

# %% [markdown]
# You can now use `a` in place of the number `10`:

# %%
a + a
# Out:
# 20

# %% [markdown]
# ## Reassigning Variables
# Python lets you reassign variables with a reference to the same object.

# %%
a = a + 10

# %%
a
# Out:
# 20

# %% [markdown]
# There's actually a shortcut for this. Python lets you add, subtract, multiply and divide numbers with reassignment using `+=`, `-=`, `*=`, and `/=`.

# %%
a += 10

# %%
a
# Out:
# 30

# %%
ctually a shortcut for this. Python lets you add, subtract, multiply and divide numbers with reassignment using +=, -=, *=, and /=.ctually a shortcut for this. Python lets you add, subtract, multiply and divide numbers with reassignment using +=, -=, *=, and /=.ctually a shortcut for this. Python lets you add, subtract, multiply and divide numbers with reassignment using +=, -=, *=, and /=.ctually a shortcut for this. Python lets you add, subtract, multiply and divide numbers with reassignment using +=, -=, *=, and /=.a *= 2

# %%
a
# Out:
# 60

# %% [markdown]
# ## Determining variable type with `type()`
# You can check what type of object is assigned to a variable using Python's built-in `type()` function. Common data types include:
# * **int** (for integer)
# * **float**
# * **str** (for string)
# * **list**
# * **tuple**
# * **dict** (for dictionary)
# * **set**
# * **bool** (for Boolean True/False)

# %%
type(a)
# Out:
# int

# %%
a = (1,2)

# %%
type(a)
# Out:
# tuple

# %% [markdown]
# ## Simple Exercise
# This shows how variables make calculations more readable and easier to follow.

# %%
my_income = 100
tax_rate = 0.1
my_taxes = my_income * tax_rate

# %%
my_taxes
# Out:
# 10.0
