# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [1, 4, 9, 16])

# %%
plt.figure(1) # optional
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro') # red dots

plt.figure(2) # optional
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'b*') # blue stars
